# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ajustar diretório para raiz do projeto (caso necessário)
import os
os.chdir(r"C:\Users\DELL\Documents\bank-analyst-project")

# Carregar features
feat = pd.read_csv("data/processed/features_table.csv")
feat.head()
# Out:
#    customer_id  recency_days  frequency  monetary  products_count  churn_90d
# 0            1         123.0        3.0   5754.60               0          0
# 1            2          92.0        3.0   9871.74               0          0
# 2            3          62.0        5.0  10495.10               0          0
# 3            4          31.0        4.0   6433.98               0          1
# 4            5          62.0        4.0   8384.69               0          0

# %%
feat['age'].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Distribuição de idade dos clientes")
plt.xlabel("Idade")
plt.ylabel("Número de clientes")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ...

# %%
feat.columns
# Out:
# Index(['customer_id', 'recency_days', 'frequency', 'monetary',
#        'products_count', 'churn_90d'],
#       dtype='object')

# %%
feat['recency_days'].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Distribuição de recency_days dos clientes")
plt.xlabel("Dias desde a última transação")
plt.ylabel("Número de clientes")
plt.show()

# %%
feat['recency_days'].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Distribuição de recency_days dos clientes")
plt.xlabel("Dias desde a última transação")
plt.ylabel("Número de clientes")
plt.show()

# %%
if 'income_bracket' in feat.columns:
    feat.groupby('income_bracket')['products_count'].mean().plot(kind='bar', color='orange')
    plt.title("Média de produtos por faixa de renda")
    plt.ylabel("Número médio de produtos")
    plt.xlabel("Faixa de renda")
    plt.show()
